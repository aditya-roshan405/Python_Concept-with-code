# %% [markdown]
# Problem 1:

# %%
# break
for i in range(1, 6):
    if i == 3:
        break
    print(i)

# continue
for i in range(1, 6):
    if i == 3:
        continue
    print(i)

# pass
for i in range(1, 4):
    if i == 2:
        pass
    print(i)
# Out:
# 1
# 2
# 1
# 2
# 4
# 5
# 1
# 2
# 3

# %% [markdown]
# Problem 2:

# %%
celsius = [0, 20, 30, 40]

fahrenheit = list(map(lambda c: (c * 9/5) + 32, celsius))

print(fahrenheit)
# Out:
# [32.0, 68.0, 86.0, 104.0]

# %% [markdown]
# Problem 3:

# %%
numbers = [12, 5, 8, 20, 3, 10]

numbers.sort()

print("Second Smallest:", numbers[1])
# Out:
# Second Smallest: 5

# %% [markdown]
# Problem 4:

# %%
year = int(input("Enter year: "))

if (year % 400 == 0) or (year % 4 == 0 and year % 100 != 0):
    print("Leap Year")
else:
    print("Not a Leap Year")
# Out:
# Enter year: 2027
# Not a Leap Year

# %% [markdown]
# Problem 5:

# %%
student = {
    "Aadi": 90,
    "Rahul": 75,
    "Priya": 88
}

reversed_dict = {value: key for key, value in student.items()}

print(reversed_dict)
# Out:
# {90: 'Aadi', 75: 'Rahul', 88: 'Priya'}

# %% [markdown]
# Problem 6:

# %%
values = [True, False, True]

print(any(values))
print(all(values))
# Out:
# True
# False

# %% [markdown]
# Problem 7:

# %%
nested = [[1, 2], [3, 4], [5, 6]]

flat = []

for sublist in nested:
    flat.extend(sublist)

print(flat)
# Out:
# [1, 2, 3, 4, 5, 6]

# %% [markdown]
# Problem 8:

# %%
list1 = [1, 2]

list1.append([3, 4])
print(list1)

list2 = [1, 2]
list2.extend([3, 4])
print(list2)
# Out:
# [1, 2, [3, 4]]
# [1, 2, 3, 4]

# %% [markdown]
# Problem 9:

# %%
sentence = input("Enter a sentence: ")

words = sentence.split()

longest = max(words, key=len)

print("Longest Word:", longest)
# Out:
# Enter a sentence: College
# Longest Word: College

# %% [markdown]
# Problem 10:

# %%
from collections import Counter

items = ["apple", "banana", "apple", "orange",
         "banana", "apple", "grape", "banana"]

counter = Counter(items)

print(counter.most_common(3))
# Out:
# [('apple', 3), ('banana', 3), ('orange', 1)]
