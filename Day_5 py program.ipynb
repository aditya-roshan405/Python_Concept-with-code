# %% [markdown]
# Program 2:

# %%
while True:
    user_input = input("Enter a command (type 'exit' to quit): ")

    if user_input.lower() == "exit":
        print("Program terminated.")
        break

    print("You entered:", user_input)
# Out:
# Enter a command (type 'exit' to quit): exit
# Program terminated.

# %% [markdown]
# Program 2:

# %%
students = {
    "Aditya": 85,
    "Rahul": 30,
    "Priya": 76,
    "Anjali": 40,
    "Rohan": 22
}

print("Students who passed:")

for name, marks in students.items():
    if marks > 35:
        print(name, ":", marks)
# Out:
# Students who passed:
# Aditya : 85
# Priya : 76
# Anjali : 40

# %% [markdown]
# Program 3:

# %%
numbers = [1, 2, 3, 4, 5]

squares = [num ** 2 for num in numbers]

print(squares)
# Out:
# [1, 4, 9, 16, 25]

# %% [markdown]
# Program4:

# %%
dict1 = {"a": 1, "b": 2}
dict2 = {"c": 3, "d": 4}

merged = dict1 | dict2

print(merged)
# Out:
# {'a': 1, 'b': 2, 'c': 3, 'd': 4}

# %% [markdown]
# Program 5:

# %%
text = input("Enter a string: ")

frequency = {}

for ch in text:
    frequency[ch] = frequency.get(ch, 0) + 1

print(frequency)
# Out:
# Enter a string: Hello trainers !
# {'H': 1, 'e': 2, 'l': 2, 'o': 1, ' ': 2, 't': 1, 'r': 2, 'a': 1, 'i': 1, 'n': 1, 's': 1, '!': 1}

# %% [markdown]
# Program 6:

# %%
fruits = ["Apple", "Banana", "Mango"]

for index, fruit in enumerate(fruits):
    print(index, fruit)
# Out:
# 0 Apple
# 1 Banana
# 2 Mango

# %% [markdown]
# Program 7:

# %%
set1 = {1, 2, 3, 4, 5}
set2 = {3, 4, 5, 6, 7}

common = set1.intersection(set2)

print(common)
# Out:
# {3, 4, 5}

# %% [markdown]
# Program 8:

# %%
names = ["Aadi", "Rahul", "Priya"]
marks = [90, 75, 88]

student_dict = dict(zip(names, marks))

print(student_dict)
# Out:
# {'Aadi': 90, 'Rahul': 75, 'Priya': 88}

# %% [markdown]
# Program 9:

# %%
matrix = [
    [1, 2, 3],
    [4, 5, 6],
    [7, 8, 9]
]

print("Middle Element:", matrix[1][1])
# Out:
# Middle Element: 5

# %% [markdown]
# Program 10:

# %%
student_marks = {
    "Aadi": 90,
    "Rahul": 75,
    "Priya": 88,
    "Anjali": 65
}

sorted_dict = dict(sorted(student_marks.items(), key=lambda item: item[1]))

print(sorted_dict)
# Out:
# {'Anjali': 65, 'Rahul': 75, 'Priya': 88, 'Aadi': 90}
